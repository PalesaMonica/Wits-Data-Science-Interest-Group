# %% [markdown]
# ### Exercise 1
#
# - Given the film_data.csv and SQL_QUERIES.sql write the pandas version commands for it
# - For each command write a short description of what you notice in your data

# %%
import pandas as pd
import numpy as np
