# %% [markdown]
# ## Exercise 1: Exploring the Simulated Student Dataset (Pandas)
#
# Using the provided simulated student dataset, perform the following exploratory data analysis tasks in Pandas:
#
# 1. Check the size of the dataset
# Determine the number of rows and columns in the dataset.
#
# 2. Check for missing values
# - Identify whether there are any missing (null) values in the dataset.
# - If present, determine how many missing values exist per column.
#
# 3. Inspect the data types
# Examine the data type of each column.
#
# 4. Students with sleeping issues
#
# - Determine how many students report having sleeping issues.
# - Check for duplicate records
# - Investigate whether the dataset contains duplicate rows.
#    - Hint: Use the duplicated() function in Pandas.
# - Students in Year 2
#    - Count how many students are in their second year of study.
# - Most popular major
# - Identify which major has the highest number of students enrolled.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  **About This Dataset**
#
# This is a simulated dataset representing sleep behaviors and academic performance, among college students. It was created for the purpose of learning.
#
# The dataset includes 50 fictional students and aims to explore how sleep habits relate to stress levels and GPA.
#
# Columns Included
#
#     Student_ID: Unique ID
#     Sleep_Hours: Average nightly sleep (hours)
#     Stress_Level: Self-reported stress (1–10)
#     Sleep_Issues: Whether student reports sleep trouble
#     Use_Sleep_Tech: Use of apps or tech tools for sleep
#     Year: College year (1st to 4th)
#     GPA: Simulated GPA based on sleep & stress
#
# https://www.kaggle.com/datasets/valencaycodes/simulated-student-sleep-dataset

# %%
"""
This are some of the functions you have to use

df.shape
df.isnull().sum()
df.dtypes
df.info()
df["column"].value_counts()
"""

# %%
data=pd.read_csv("sim_student_sleep_data(1).csv")

# %%
data.head()
# Out:
#   Student_ID  Sleep_Hours  Stress_Level  Year    Major Use_Sleep_Tech  \
# 0    STUD001          6.9           4.0     2     Arts            Yes
# 1    STUD002          6.0           6.0     2  Science             No
# 2    STUD003          7.0           5.0     1  Science             No
# 3    STUD004          7.6           4.0     1     Arts            Yes
# 4    STUD005          5.6           5.0     1  Science            Yes
#
#    Amount_Coffee_consumed Sleep_Issues   GPA
# 0                       1           No  3.97
# 1                       1          Yes  3.64
# 2                       1          Yes  3.83
# 3                       5          Yes  3.88
# 4                       4           No  3.46
